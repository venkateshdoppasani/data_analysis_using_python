# %%
import pandas as pd

# %%
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import LogisticRegression
log=LogisticRegression()
LR=LinearRegression()
import pandas as pd

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
mydf=pd.read_csv("/content/WA_Fn-UseC_-HR-Employee-Attrition.csv")
mydf
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# ...

# %%
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import LogisticRegression
log=LogisticRegression()
LR=LinearRegression()
import pandas as pd

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
DTC=DecisionTreeClassifier()

# %%
from matplotlib import pyplot as plt
import numpy as np

# %%
column=['DistanceFromHome','TotalWorkingYears','YearsAtCompany']

# %%
Target=mydf['Attrition']

# %%
features=mydf[column]

# %%
DTC.fit(features,Target)
# Out:
# DecisionTreeClassifier()

# %%
DTC.predict([[2,7,0]])
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# array(['Yes'], dtype=object)

# %%
p=int(input("Enter Distance from home"))
q=int(input("Enter Total working years"))
r=int(input("Enter years at company "))
y=DTC.predict([[p,q,r]])
if y == 'Yes':
  print("Attrition is yes")
else:
  print("Attrition is no")
# Out:
# Enter Distance from home2
# Enter Total working years7
# Enter years at company 0
# Attrition is yes
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(

# %%
import os
output_dir="tree visualizations"
os.makedirs(output_dir,exist_ok=True)

# %%
for i,tree in enumerate(DTC.estimators_):
  tree_dot_file=os.path.join(output_dir,f"tree_{i}.dot")
  tree_dot_file=os.path.join(output_dir,f"tree_{i}.png")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-20-e6bfc48888fe> in <cell line: 1>()
# ----> 1 for i,tree in enumerate(DTC.estimators_):
#       2   tree_dot_file=os.path.join(output_dir,f"tree_{i}.dot")
#       3   tree_dot_file=os.path.join(output_dir,f"tree_{i}.png")
#
# AttributeError: 'DecisionTreeClassifier' object has no attribute 'estimators_'

# %%
from sklearn.tree  import export_graphviz
export_graphviz(tree,out_file=tree_dot_file,feature_names=["Literacy","Cleanliness","Crime_Rate"],class_names=[str(cls) for cls in ran.classes_],filled=True,rounded=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-bd25b5a1c6bd> in <cell line: 2>()
#       1 from sklearn.tree  import export_graphviz
# ----> 2 export_graphviz(tree,out_file=tree_dot_file,feature_names=["Literacy","Cleanliness","Crime_Rate"],class_names=[str(cls) for cls in ran.classes_],filled=True,rounded=True)
#
# NameError: name 'tree' is not defined
