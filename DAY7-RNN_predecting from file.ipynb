# %%
import numpy as np
from keras.models import Sequential
from keras.layers import SimpleRNN,Dense,Embedding
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from keras.utils import to_categorical

# %%
import pandas as pd

# %%
df=pd.read_csv("/content/earth.txt")
df
# Out:
# Empty DataFrame
# Columns: [Earth is the third planet from the Sun and the only astronomical object known to harbor life. This is enabled by Earth being a water world,  the only one in the Solar System sustaining liquid surface water. Almost all of Earth's water is contained in its global ocean,  covering 70.8% of Earth's crust. The remaining 29.2% of Earth's crust is land,  most of which is located in the form of continental landmasses within one hemisphere,  Earth's land hemisphere. Most of Earth's land is somewhat humid and covered by vegetation,  while large sheets of ice at Earth's polar deserts retain more water than Earth's groundwater,  lakes,  rivers and atmospheric water combined. Earth's crust consists of slowly moving tectonic plates,  which interact to produce mountain ranges,  volcanoes,  and earthquakes. Earth has a liquid outer core that generates a magnetosphere capable of deflecting most of the destructive solar winds and cosmic radiation.]
# Index: []

# %%
import tensorflow

# %%
sentences=['vasavi college','engineering college','taddepalli','gudem','i','am']

# %%
tokenizer=Tokenizer()
tokenizer.fit_on_texts(sentences)
total_words=len(tokenizer.word_index)+1
print(total_words)
# Out:
# 8

# %%
#creating input sequence and their corresponding next word
input_sequences = []
for sentence in sentences:
    tokenized_sentence = tokenizer.texts_to_sequences([sentence])[0]
    for i in range(1, len(tokenized_sentence)):
        n_gram_sequence = tokenized_sentence[:i+1]
        input_sequences.append(n_gram_sequence)
input_sequences
# Out:
# [[2, 1], [3, 1]]

# %%
# Padding sequences for consistent input size
max_sequence_length = max([len(seq) for seq in input_sequences])
input_sequences = pad_sequences(input_sequences, maxlen=max_sequence_length,padding='pre')

# %%
# Creating input and output data
X, y = input_sequences[:, :-1], input_sequences[:, -1]
y = to_categorical(y, num_classes=total_words)

# %%
# Building a simple RNN model
model = Sequential()
model.add(Embedding(input_dim=total_words, output_dim=50, input_length=max_sequence_length-1))
model.add(SimpleRNN(100, return_sequences=True))
model.add(SimpleRNN(100))
model.add(Dense(total_words, activation='softmax'))

# %%
model.compile(optimizer='adam',loss='categorical_crossentropy',metrics=['accuracy'])

# %%
#Test:
# Generating text using the trained model
seed_text = input("Enter the starting word: ")
next_words = int(input("Enter how many words to predict: "))

for _ in range(next_words):
    tokenized_seed = tokenizer.texts_to_sequences([seed_text])[0]
    tokenized_seed = pad_sequences([tokenized_seed], maxlen=max_sequence_length-1, padding='pre')
    predicted_word_index = np.argmax(model.predict(tokenized_seed), axis=-1)
    predicted_word = tokenizer.index_word[predicted_word_index[0]]
    seed_text += " " + predicted_word

print(seed_text)
# Out:
# Enter the starting word: I
# Enter how many words to predict: 7
# 1/1 [==============================] - 0s 23ms/step
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-15-6e241700c586> in <cell line: 6>()
#       8     tokenized_seed = pad_sequences([tokenized_seed], maxlen=max_sequence_length-1, padding='pre')
#       9     predicted_word_index = np.argmax(model.predict(tokenized_seed), axis=-1)
# ---> 10     predicted_word = tokenizer.index_word[predicted_word_index[0]]
#      11     seed_text += " " + predicted_word
#      12
#
# KeyError: 0

# %%
model.fit(X,y,epochs=50,verbose=2)
# Out:
# Epoch 1/50
# 1/1 - 3s - loss: 2.1040 - accuracy: 0.0000e+00 - 3s/epoch - 3s/step
# Epoch 2/50
# 1/1 - 0s - loss: 2.0563 - accuracy: 0.5000 - 11ms/epoch - 11ms/step
# Epoch 3/50
# 1/1 - 0s - loss: 2.0089 - accuracy: 1.0000 - 14ms/epoch - 14ms/step
# Epoch 4/50
# 1/1 - 0s - loss: 1.9609 - accuracy: 1.0000 - 11ms/epoch - 11ms/step
# Epoch 5/50
# 1/1 - 0s - loss: 1.9114 - accuracy: 1.0000 - 13ms/epoch - 13ms/step
# Epoch 6/50
# 1/1 - 0s - loss: 1.8594 - accuracy: 1.0000 - 12ms/epoch - 12ms/step
# Epoch 7/50
# 1/1 - 0s - loss: 1.8042 - accuracy: 1.0000 - 12ms/epoch - 12ms/step
# Epoch 8/50
# 1/1 - 0s - loss: 1.7450 - accuracy: 1.0000 - 12ms/epoch - 12ms/step
# Epoch 9/50
# 1/1 - 0s - loss: 1.6811 - accuracy: 1.0000 - 12ms/epoch - 12ms/step
# Epoch 10/50
# 1/1 - 0s - loss: 1.6120 - accuracy: 1.0000 - 10ms/epoch - 10ms/step
# Epoch 11/50
# 1/1 - 0s - loss: 1.5371 - accuracy: 1.0000 - 11ms/epoch - 11ms/step
# Epoch 12/50
# 1/1 - 0s - loss: 1.4560 - accuracy: 1.0000 - 10ms/epoch - 10ms/step
# Epoch 13/50
# 1/1 - 0s - loss: 1.3687 - accuracy: 1.0000 - 9ms/epoch - 9ms/step
# Epoch 14/50
# 1/1 - 0s - loss: 1.2750 - accuracy: 1.0000 - 11ms/epoch - 11ms/step
# Epoch 15/50
# 1/1 - 0s - loss: 1.1752 - accuracy: 1.0000 - 12ms/epoch - 12ms/step
# Epoch 16/50
# 1/1 - 0s - loss: 1.0699 - accuracy: 1.0000 - 10ms/epoch - 10ms/step
# Epoch 17/50
# 1/1 - 0s - loss: 0.9601 - accuracy: 1.0000 - 10ms/epoch - 10ms/step
# Epoch 18/50
# 1/1 - 0s - loss: 0.8473 - accuracy: 1.0000 - 12ms/epoch - 12ms/step
# Epoch 19/50
# 1/1 - 0s - loss: 0.7337 - accuracy: 1.0000 - 10ms/epoch - 10ms/step
# Epoch 20/50
# 1/1 - 0s - loss: 0.6219 - accuracy: 1.0000 - 10ms/epoch - 10ms/step
# Epoch 21/50
# 1/1 - 0s - loss: 0.5148 - accuracy: 1.0000 - 13ms/epoch - 13ms/step
# Epoch 22/50
# 1/1 - 0s - loss: 0.4155 - accuracy: 1.0000 - 10ms/epoch - 10ms/step
# Epoch 23/50
# 1/1 - 0s - loss: 0.3268 - accuracy: 1.0000 - 11ms/epoch - 11ms/step
# Epoch 24/50
# 1/1 - 0s - loss: 0.2507 - accuracy: 1.0000 - 11ms/epoch - 11ms/step
# Epoch 25/50
# 1/1 - 0s - loss: 0.1879 - accuracy: 1.0000 - 10ms/epoch - 10ms/step
# Epoch 26/50
# 1/1 - 0s - loss: 0.1381 - accuracy: 1.0000 - 16ms/epoch - 16ms/step
# Epoch 27/50
# 1/1 - 0s - loss: 0.1001 - accuracy: 1.0000 - 17ms/epoch - 17ms/step
# Epoch 28/50
# 1/1 - 0s - loss: 0.0718 - accuracy: 1.0000 - 12ms/epoch - 12ms/step
# Epoch 29/50
# 1/1 - 0s - loss: 0.0514 - accuracy: 1.0000 - 13ms/epoch - 13ms/step
# Epoch 30/50
# 1/1 - 0s - loss: 0.0368 - accuracy: 1.0000 - 12ms/epoch - 12ms/step
# Epoch 31/50
# 1/1 - 0s - loss: 0.0265 - accuracy: 1.0000 - 12ms/epoch - 12ms/step
# Epoch 32/50
# 1/1 - 0s - loss: 0.0193 - accuracy: 1.0000 - 11ms/epoch - 11ms/step
# Epoch 33/50
# 1/1 - 0s - loss: 0.0142 - accuracy: 1.0000 - 11ms/epoch - 11ms/step
# Epoch 34/50
# 1/1 - 0s - loss: 0.0106 - accuracy: 1.0000 - 11ms/epoch - 11ms/step
# Epoch 35/50
# 1/1 - 0s - loss: 0.0080 - accuracy: 1.0000 - 11ms/epoch - 11ms/step
# Epoch 36/50
# 1/1 - 0s - loss: 0.0061 - accuracy: 1.0000 - 11ms/epoch - 11ms/step
# Epoch 37/50
# 1/1 - 0s - loss: 0.0048 - accuracy: 1.0000 - 10ms/epoch - 10ms/step
# Epoch 38/50
# 1/1 - 0s - loss: 0.0038 - accuracy: 1.0000 - 9ms/epoch - 9ms/step
# Epoch 39/50
# 1/1 - 0s - loss: 0.0031 - accuracy: 1.0000 - 10ms/epoch - 10ms/step
# Epoch 40/50
# 1/1 - 0s - loss: 0.0025 - accuracy: 1.0000 - 9ms/epoch - 9ms/step
# Epoch 41/50
# 1/1 - 0s - loss: 0.0021 - accuracy: 1.0000 - 11ms/epoch - 11ms/step
# Epoch 42/50
# 1/1 - 0s - loss: 0.0017 - accuracy: 1.0000 - 10ms/epoch - 10ms/step
# Epoch 43/50
# 1/1 - 0s - loss: 0.0015 - accuracy: 1.0000 - 11ms/epoch - 11ms/step
# Epoch 44/50
# 1/1 - 0s - loss: 0.0013 - accuracy: 1.0000 - 11ms/epoch - 11ms/step
# Epoch 45/50
# 1/1 - 0s - loss: 0.0011 - accuracy: 1.0000 - 11ms/epoch - 11ms/step
# Epoch 46/50
# 1/1 - 0s - loss: 9.8656e-04 - accuracy: 1.0000 - 10ms/epoch - 10ms/step
# Epoch 47/50
# 1/1 - 0s - loss: 8.7907e-04 - accuracy: 1.0000 - 10ms/epoch - 10ms/step
# Epoch 48/50
# 1/1 - 0s - loss: 7.9063e-04 - accuracy: 1.0000 - 10ms/epoch - 10ms/step
# Epoch 49/50
# 1/1 - 0s - loss: 7.1732e-04 - accuracy: 1.0000 - 10ms/epoch - 10ms/step
# Epoch 50/50
# 1/1 - 0s - loss: 6.5591e-04 - accuracy: 1.0000 - 11ms/epoch - 11ms/step
